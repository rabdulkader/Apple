# %%
import numpy as np
import random,copy,time
import pygame as pg

# %%
#set nn structure [input nodes,x hiddenlayers with x nodes....,output nodes, o for offset]
#function to generate random chromosomes
def chromosome_generetor(structure):
    x=[]
    for i in range(0,len(structure)-1):
        k=structure[i]*structure[i+1]
        x.append(k)
    x=sum(x)
    return 2*np.random.random((x,))-1 

#function to arrange the weights for each layers 
def weights_classifier(structure,chromosome):
    weights_list=[]
    for i in range(0,len(structure)-2):
        if i == 0:
            a=0
            b=structure[i]*structure[i+1]
        else:
            a=b
            b=a+(structure[i]*structure[i+1])
        r=structure[i]
        c=structure[i+1]
        w=np.reshape(np.matrix(chromosome[a:b]),(r,c))
        weights_list.append(w)
    return weights_list

def sigmoid(x):
    return 1/(1+np.exp(-x))

def feed_forward(structure,chromosome,train_input):
    weights_list=weights_classifier(structure,chromosome)
    for i in range(len(weights_list)):
        if i==0:
            output=sigmoid(np.dot(train_input,weights_list[i]))
        else:
            output=sigmoid(np.dot(output,weights_list[i]))     
    return output
 
def playing(structure,chromosome,train_input):
    decision=feed_forward(structure,chromosome,train_input)
    return np.array(decision)

# %%
def visionApple(snake,apple):
    vision_apple=[0, 0, 0, 0, 0, 0, 0, 0]
    n=snake[0][1]
    s=snake[0][1]
    w=snake[0][0]
    e=snake[0][0]

    for i in range(10):

        n-=60
        s+=60
        w-=60
        e+=60

        if apple[1]==n and apple[0]==snake[0][0]:
            vision_apple[0]=1

        if apple[1]==s and apple[0]==snake[0][0]:
            vision_apple[1]=1  

        if apple[0]==w and apple[1]==snake[0][1]:
            vision_apple[2]=1      

        if apple[0]==e and apple[1]==snake[0][1]:
            vision_apple[3]=1        

        if apple[1]==n and apple[0]==w:
            vision_apple[4]=1    

        if apple[1]==s and apple[0]==w:
            vision_apple[5]=1    

        if apple[1]==n and apple[0]==e:
            vision_apple[6]=1 

        if apple[1]==s and apple[0]==e:
            vision_apple[7]=1
            
    return vision_apple

def visionBody(snake,apple):
    vision_body=[0, 0, 0, 0, 0, 0, 0, 0]

    for i in range(1,len(snake)):
        
        n=snake[0][1]
        s=snake[0][1]
        w=snake[0][0]
        e=snake[0][0]
        
        for _ in range(10):

            n-=60
            s+=60
            w-=60
            e+=60

            if snake[i][1]==n and snake[i][0]==snake[0][0]:
                vision_body[0]=1

            if snake[i][1]==s and snake[i][0]==snake[0][0]:
                vision_body[1]=1  

            if snake[i][0]==w and snake[i][1]==snake[0][1]:
                vision_body[2]=1      

            if snake[i][0]==e and snake[i][1]==snake[0][1]:
                vision_body[3]=1        

            if snake[i][1]==n and snake[i][0]==w:
                vision_body[4]=1    

            if snake[i][1]==s and snake[i][0]==w:
                vision_body[5]=1    

            if snake[i][1]==n and snake[i][0]==e:
                vision_body[6]=1 

            if snake[i][1]==s and snake[i][0]==e:
                vision_body[7]=1
            
    return vision_body

def visionWall(snake):
    #            nw,sw,ww,ew
    vision_wall=[0, 0, 0, 0]
    
    vision_wall[0]=int((snake[0][1]/60))
    vision_wall[1]=int(((600-snake[0][1])/60)-1)
    vision_wall[2]=int((snake[0][0]/60))
    vision_wall[3]=int(((600-snake[0][0])/60)-1)
    
    return vision_wall

def move_d(decision):
    
    move=[0,0,0,0]
    j=np.amax(decision)
    k=np.where(decision==j)
    i=k[1][0]
    #print('\nj= ',j,' k= ',k,' i= ',i)
    move[i]=1
    
    return move

# %%
def game(structure,chromosome):
    
    frame_w=600
    frame_h=600
    
    #pg.init()
    #screen = pg.display.set_mode((frame_w,frame_h))

    white=[255,255,255]
    red=[255,0,0]
    black=[0,0,0]
    green=[0,255,0]
    
    running=True
    apple_present=False

    score=0
    steps=0
    apple_steps=200

    x=[]
    y=[]

    for i in range(0,frame_w,60):
        x.append(i)
        y.append(i)

    grid=[]
    for i in range(len(x)):
        for j in range(len(y)):
            grid.append((x[i],y[j]))

    snake_head=grid[55]
    snake=[snake_head]
    
    while running:
        
        #pg.event.get()
        
        grid_c=copy.deepcopy(grid)

        if apple_present==False:
            for body in snake:
                if body in grid:
                    grid.remove(body)
            apple=random.choice(grid)
            apple_present=True

        vision_apple=visionApple(snake,apple)

        #print('\nApple= ',vision_apple)

        #print('snake= ',snake,' apple= ',apple,' Score= ',score,' steps= ',steps)

        if steps==0:
            vision_body=[0, 0, 0, 0, 0, 0, 0, 0]
            vision_wall=[0, 0, 0, 0]
            head_direction=[0, 0, 0, 0]
            tail_direction=[0, 0, 0, 0]

        nn_input=np.concatenate([vision_apple,vision_body,vision_wall,head_direction,tail_direction])

        ###call nn
        decision=playing(structure,chromosome,nn_input)
        #### call move
        move=move_d(decision)
        #print(decision)
        

        snake_c=copy.deepcopy(snake)

        if move ==[1,0,0,0]:
            snake[0]=(snake[0][0],snake[0][1]-60)
        if move ==[0,1,0,0]:
            snake[0]=(snake[0][0],snake[0][1]+60)
        if move ==[0,0,1,0]:
            snake[0]=(snake[0][0]-60,snake[0][1])
        if move ==[0,0,0,1]:
            snake[0]=(snake[0][0]+60,snake[0][1])
            
            
        for i in range(1,len(snake)):

            if snake[i][0]==snake[0][0] and snake[i][1]==snake[0][1]:
                #print('snake= ',snake,' apple= ',apple,' Score= ',score,' steps= ',steps)
                #print('Body Collision')
                running=False
                

        for i in range(1,len(snake)):
            snake[i]=snake_c[i-1]

        if snake[0]==apple:
            apple_present=False
            snake.append(snake_c[-1])
            #snake_c=copy.deepcopy(snake)
            score+=1
            apple_steps=200
            #print('Apple Gone')

        if len(snake)==1:
            vision_body=[0, 0, 0, 0, 0, 0, 0, 0]
        elif len(snake)>1:
            vision_body=visionBody(snake,apple)
        #print('Body= ',vision_body)

        if snake[0][0] < 0 or snake[0][0] > 540 or snake[0][1] < 0 or snake[0][1] > 540 :
            #print('Wall Collision')
            running=False


        if len(snake) != 1:        
            if (snake_c[-1][1]-snake[-1][1])<0:
                tail_direction=[0,1,0,0]
            if (snake_c[-1][1]-snake[-1][1])>0:
                tail_direction=[1,0,0,0]
            if (snake_c[-1][0]-snake[-1][0])<0:
                tail_direction=[0,0,0,1]
            if (snake_c[-1][0]-snake[-1][0])>0:
                tail_direction=[0,0,1,0]
        else:
            tail_direction=move

        head_direction=move

        vision_wall=visionWall(snake)
        
        steps+=1
        apple_steps -= 1
        if apple_steps == 0:
            running=False
        #print(running)
 #       screen.fill(white)
#
   #     for i in range(len(grid_c)):
  #          g_grid=pg.Rect(grid_c[i][0],grid_c[i][1],60,60)
 #           pg.draw.rect(screen,black,g_grid,1)
#
  #      g_apple=pg.Rect(apple[0],apple[1],60,60)
 #       pg.draw.rect(screen,green,g_apple)
#
       # for i in range(len(snake)):
      #      if i==0:
     #           color=red
    #        else:
   #             color=black
  #          g_snake=pg.Rect(snake[i][0],snake[i][1],60,60)
 #           pg.draw.rect(screen,color,g_snake)
#
#        pg.display.flip()
        
        #time.sleep(0.2)
    return score,steps

# %%
population=[]

def populate(size):
    
    initial_pop=[None]*size
    
    for i in range(size):
        chromosome=chromosome_generetor(structure)
        initial_pop[i]=chromosome
    
    return initial_pop

def fitness(population,size,structure):
    
    score=[None]*size
    apples=[None]*size
    for index,chromosome in enumerate(population):
        
        apple,steps=game(structure,chromosome)
        apples[index]=(apple)
        point=(steps+((2**apple)+200*(apple**2.1))-(0.25*(steps**1.3)*(apple**1.2)))*-1
        score[index]=point,chromosome,apple,steps,index
        
    top_score=np.array(score)[np.array(score)[:,0].argsort()]
    #print(top_score)
    order=[None]*size
    for i in range(size):
        order[i]=top_score[i][1]
    
    top_snakes=np.array(order)[:int(size*0.1)]
    warrior=top_score[0]
    best_apple=np.amax(apples)
    #print(top_score[0][2],top_score[0][3],top_score[99][2],top_score[99][3])
    return top_snakes,warrior,best_apple

# %%
def mutation(child,m_rate):
    
    loop=int(round((len(child)/100)*m_rate))
    #x=len(child)
    #child=np.reshape(child,(1,x))
    x=child.tolist()
    #print(len(x))
    for _ in range(loop):
        i=random.randrange(0,len(x),1)
        #print(i)
        child[i]=child[i]+(2*np.random.random()-1)
    
    #child=np.reshape(child,(x,1))
    return child

def mate(population,size,m_rate,pattern):
    
    new_pop=[]
    for _ in range(int(size/2)):
        
        #print(len(population))
        p1=population[np.random.randint(0,len(population))]
        p2=population[np.random.randint(0,len(population))]
        

        if pattern=='single_point':
            x=int(round(((len(p1)/100)*50)+0.1))
            for i in range(2):
            
                if i == 0:
                    child = np.concatenate(([p1[:x],p2[x:]]))

                if i == 1:
                    child = np.concatenate(([p2[:x],p1[x:]]))
                
                child=mutation(np.array(child),m_rate)
                new_pop.append(child)
        
        if pattern=='multi_point':
            child=[None]*len(p1)
            for i in range(0,len(child),2):
                if i == len(child)-1:
                    child[i]=p1[i]
                else:
                    child[i]=p1[i]
                    child[i+1]=p2[i+1]       
            child=mutation(np.array(child),m_rate)
            new_pop.append(child)

            child=[None]*len(p1)
            for i in range(0,len(child),2):
                if i == len(child)-1:
                    child[i]=p2[i]
                else:
                    child[i]=p2[i]
                    child[i+1]=p1[i+1]
            child=mutation(np.array(child),m_rate)
            new_pop.append(child)
            
    return new_pop

# %%
def cycle(generation,population,size,m_rate,structure,pattern):
    population=populate(size)
    gen=0
    for _ in range(generation):
        gen+=1
        population,warrior,best_apple=fitness(population,size,structure)
        population=mate(population,size,m_rate,pattern)
        path=r'weights\gen_'+str(gen)+'.txt'
        file=open(path,'w')
        file.write(str(warrior[1].tolist()))
        file.close()
        print('Generation: ',str(gen),'-----','Fittest: ',warrior[0],' Score= ',warrior[2],' Steps= ',warrior[3])
    return warrior

# %%
structure=[28,14,7,4,0]

size=500
generations=5000
m_rate=100
pattern='single_point'

warrior=cycle(generations,population,size,m_rate,structure,pattern)
# Out:
# Generation:  1 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  2 ----- Fittest:  -207.67769230196657  Score=  1  Steps=  12
# Generation:  3 ----- Fittest:  -861.7646561124443  Score=  2  Steps=  5
# Generation:  4 ----- Fittest:  -207.67769230196657  Score=  1  Steps=  12
# Generation:  5 ----- Fittest:  -209.05685880685382  Score=  1  Steps=  17
# Generation:  6 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  7 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  8 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  9 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  10 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  11 ----- Fittest:  -208.54996232184004  Score=  1  Steps=  15
# Generation:  12 ----- Fittest:  -208.54996232184004  Score=  1  Steps=  15
# Generation:  13 ----- Fittest:  -209.7177197388421  Score=  1  Steps=  20
# Generation:  14 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  15 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  16 ----- Fittest:  -208.274858286695  Score=  1  Steps=  14
# Generation:  17 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  18 ----- Fittest:  -207.0118442125778  Score=  1  Steps=  10
# Generation:  19 ----- Fittest:  -208.81041316002373  Score=  1  Steps=  16
# Generation:  20 ----- Fittest:  -207.98437500562986  Score=  1  Steps=  13
# Generation:  21 ----- Fittest:  -207.0118442125778  Score=  1  Steps=  10
# Generation:  22 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  23 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  24 ----- Fittest:  -207.0118442125778  Score=  1  Steps=  10
# Generation:  25 ----- Fittest:  -207.0118442125778  Score=  1  Steps=  10
# Generation:  26 ----- Fittest:  -209.91345232016363  Score=  1  Steps=  21
# Generation:  27 ----- Fittest:  -861.7646561124443  Score=  2  Steps=  5
# Generation:  28 ----- Fittest:  -207.35387486243818  Score=  1  Steps=  11
# Generation:  29 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  30 ----- Fittest:  -209.05685880685382  Score=  1  Steps=  17
# Generation:  31 ----- Fittest:  -206.26786803385278  Score=  1  Steps=  8
# Generation:  32 ----- Fittest:  -207.35387486243818  Score=  1  Steps=  11
# Generation:  33 ----- Fittest:  -207.67769230196657  Score=  1  Steps=  12
# Generation:  34 ----- Fittest:  -207.98437500562986  Score=  1  Steps=  13
# Generation:  35 ----- Fittest:  -207.35387486243818  Score=  1  Steps=  11
# Generation:  36 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  37 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  38 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  39 ----- Fittest:  -207.0118442125778  Score=  1  Steps=  10
# Generation:  40 ----- Fittest:  -857.0056812679038  Score=  2  Steps=  15
# Generation:  41 ----- Fittest:  -208.81041316002373  Score=  1  Steps=  16
# Generation:  42 ----- Fittest:  -207.98437500562986  Score=  1  Steps=  13
# Generation:  43 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  44 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  45 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  46 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  47 ----- Fittest:  -208.54996232184004  Score=  1  Steps=  15
# Generation:  48 ----- Fittest:  -207.98437500562986  Score=  1  Steps=  13
# Generation:  49 ----- Fittest:  -209.91345232016363  Score=  1  Steps=  21
# Generation:  50 ----- Fittest:  -208.81041316002373  Score=  1  Steps=  16
# Generation:  51 ----- Fittest:  -861.7646561124443  Score=  2  Steps=  5
# Generation:  52 ----- Fittest:  -858.8939211240023  Score=  2  Steps=  12
# Generation:  53 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  54 ----- Fittest:  -210.09760915968894  Score=  1  Steps=  22
# Generation:  55 ----- Fittest:  -857.6710548726496  Score=  2  Steps=  14
# Generation:  56 ----- Fittest:  -836.8331921749397  Score=  2  Steps=  36
# Generation:  57 ----- Fittest:  -210.43265239623722  Score=  1  Steps=  24
# Generation:  58 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  59 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  60 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  61 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  62 ----- Fittest:  -209.7177197388421  Score=  1  Steps=  20
# Generation:  63 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  64 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  65 ----- Fittest:  -211.62732584097853  Score=  1  Steps=  49
# Generation:  66 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  67 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  68 ----- Fittest:  -2008.380013272986  Score=  3  Steps=  10
# Generation:  69 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  70 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  71 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  72 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  73 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  74 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  75 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  76 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  77 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  78 ----- Fittest:  -861.7646561124443  Score=  2  Steps=  5
# Generation:  79 ----- Fittest:  -2009.7661966353833  Score=  3  Steps=  9
# Generation:  80 ----- Fittest:  -207.35387486243818  Score=  1  Steps=  11
# Generation:  81 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  82 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  83 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  84 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  85 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  86 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  87 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  88 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  89 ----- Fittest:  -2011.074016478155  Score=  3  Steps=  8
# Generation:  90 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  91 ----- Fittest:  -2009.7661966353833  Score=  3  Steps=  9
# Generation:  92 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  93 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  94 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  95 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  96 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  97 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  98 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  99 ----- Fittest:  -2008.380013272986  Score=  3  Steps=  10
# Generation:  100 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  101 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  102 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  103 ----- Fittest:  -1993.0814012686935  Score=  3  Steps=  19
# Generation:  104 ----- Fittest:  -208.54996232184004  Score=  1  Steps=  15
# Generation:  105 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  106 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  107 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  108 ----- Fittest:  -859.4473807137852  Score=  2  Steps=  11
# Generation:  109 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  110 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  111 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  112 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  113 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  114 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  115 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  116 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  117 ----- Fittest:  -859.4473807137852  Score=  2  Steps=  11
# Generation:  118 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  119 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  120 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  121 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  122 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  123 ----- Fittest:  -2005.3940303333993  Score=  3  Steps=  12
# Generation:  124 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  125 ----- Fittest:  -2005.3940303333993  Score=  3  Steps=  12
# Generation:  126 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  127 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  128 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  129 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  130 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  131 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  132 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  133 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  134 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  135 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  136 ----- Fittest:  -859.4473807137852  Score=  2  Steps=  11
# Generation:  137 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  138 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  139 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  140 ----- Fittest:  -2003.8029699123476  Score=  3  Steps=  13
# Generation:  141 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  142 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  143 ----- Fittest:  -2008.380013272986  Score=  3  Steps=  10
# Generation:  144 ----- Fittest:  -2003.8029699123476  Score=  3  Steps=  13
# Generation:  145 ----- Fittest:  -861.5198483641221  Score=  2  Steps=  6
# Generation:  146 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  147 ----- Fittest:  -859.4473807137852  Score=  2  Steps=  11
# Generation:  148 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  149 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  150 ----- Fittest:  -2003.8029699123476  Score=  3  Steps=  13
# Generation:  151 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  152 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  153 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  154 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  155 ----- Fittest:  -2008.380013272986  Score=  3  Steps=  10
# Generation:  156 ----- Fittest:  -859.4473807137852  Score=  2  Steps=  11
# Generation:  157 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  158 ----- Fittest:  -861.2109579462237  Score=  2  Steps=  7
# Generation:  159 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  160 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  161 ----- Fittest:  -2003.8029699123476  Score=  3  Steps=  13
# Generation:  162 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  163 ----- Fittest:  -2006.921054942623  Score=  3  Steps=  11
# Generation:  164 ----- Fittest:  -859.9589973340728  Score=  2  Steps=  10
# Generation:  165 ----- Fittest:  -2003.8029699123476  Score=  3  Steps=  13
# Generation:  166 ----- Fittest:  -858.8939211240023  Score=  2  Steps=  12
# Generation:  167 ----- Fittest:  -2005.3940303333993  Score=  3  Steps=  12
# Generation:  168 ----- Fittest:  -860.4258763718814  Score=  2  Steps=  9
# Generation:  169 ----- Fittest:  -860.8445823287441  Score=  2  Steps=  8
# Generation:  170 ----- Fittest:  -1998.678455314502  Score=  3  Steps=  16
