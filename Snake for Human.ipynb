# %%
import numpy as np
import random,copy
import pygame as pg



frame_w=600
frame_h=600

pg.init()
screen = pg.display.set_mode((frame_w,frame_h))

white=[255,255,255]
red=[255,0,0]
black=[0,0,0]
green=[0,255,0]

running=True
apple_present=False

score=0
steps=0

x=[]
y=[]

for i in range(0,frame_w,60):
    x.append(i)
    y.append(i)

grid=[]
for i in range(len(x)):
    for j in range(len(y)):
        grid.append((x[i],y[j]))
grid_c=copy.deepcopy(grid)
snake_head=grid[55]
snake=[snake_head]

#             n, s, w, e, nw,sw,ne,se


def visionApple(snake,apple):
    vision_apple=[0, 0, 0, 0, 0, 0, 0, 0]
    n=snake[0][1]
    s=snake[0][1]
    w=snake[0][0]
    e=snake[0][0]
    line=8
    for i in range(10):

        n-=60
        s+=60
        w-=60
        e+=60

        if apple[1]==n and apple[0]==snake[0][0]:
            vision_apple[0]=1
        if apple[1]==s and apple[0]==snake[0][0]:
            vision_apple[1]=1  
        if apple[0]==w and apple[1]==snake[0][1]:
            vision_apple[2]=1      
        if apple[0]==e and apple[1]==snake[0][1]:
            vision_apple[3]=1        
        if (apple[1]==n and apple[0]==w):
            vision_apple[4]=1    
        if apple[1]==s and apple[0]+60==w:
            vision_apple[5]=1    
        if apple[1]+60==n and apple[0]==e:
            vision_apple[6]=1 
        if (apple[1]==s and apple[0]==e):
            vision_apple[7]=1

    return vision_apple

def visionBody(snake,apple):
    vision_body=[0, 0, 0, 0, 0, 0, 0, 0]
    
    for i in range(1,len(snake)):
        
        n=snake[0][1]
        s=snake[0][1]
        w=snake[0][0]
        e=snake[0][0]
        
        for _ in range(10):

            n-=60
            s+=60
            w-=60
            e+=60

            if snake[i][1]==n and snake[i][0]==snake[0][0]:
                vision_body[0]=1
            if snake[i][1]==s and snake[i][0]==snake[0][0]:
                vision_body[1]=1  
            if snake[i][0]==w and snake[i][1]==snake[0][1]:
                vision_body[2]=1      
            if snake[i][0]==e and snake[i][1]==snake[0][1]:
                vision_body[3]=1        
            if snake[i][1]==n and snake[i][0]==w:
                vision_body[4]=1    
            if snake[i][1]==s and snake[i][0]+60==w:
                vision_body[5]=1    
            if snake[i][1]+60==n and snake[i][0]==e:
                vision_body[6]=1 
            if snake[i][1]==s and snake[i][0]==e:
                vision_body[7]=1
    return vision_body

def visionWall(snake):
    #            nw,sw,ww,ew
    vision_wall=[0, 0, 0, 0]
    
    vision_wall[0]=int((snake[0][1]/60))
    vision_wall[1]=int(((600-snake[0][1])/60)-1)
    vision_wall[2]=int((snake[0][0]/60))
    vision_wall[3]=int(((600-snake[0][0])/60)-1)
    
    return vision_wall
#def game()
while running:
    pg.event.get()
    screen.fill(white)
    if apple_present==False:
        for body in snake:
            if body in grid_c:
                grid_c.remove(body)
        apple=random.choice(grid_c)
        apple_present=True
    
    vision_apple=visionApple(snake,apple)
    
    if np.amax(vision_apple) > 0:
        line=vision_apple.index(int(np.amax(vision_apple)))
        colors=[red,red,red,red,red,red,red,red]
        colors[line]=green
    else:
        colors=[red,red,red,red,red,red,red,red]
    

    print('Apple= ',vision_apple)
    
    print('snake= ',snake,' apple= ',apple,' Score= ',score,' steps= ',steps)
    
    move=input('\nmove: ')
    
    if move =='u':
        move=[1,0,0,0]
    if move =='d':
        move=[0,1,0,0]
    if move =='l':
        move=[0,0,1,0]
    if move =='r':
        move=[0,0,0,1]
    
    snake_c=copy.deepcopy(snake)
    
    
    if move ==[1,0,0,0]:
        snake[0]=(snake[0][0],snake[0][1]-60)
    if move ==[0,1,0,0]:
        snake[0]=(snake[0][0],snake[0][1]+60)
    if move ==[0,0,1,0]:
        snake[0]=(snake[0][0]-60,snake[0][1])
    if move ==[0,0,0,1]:
        snake[0]=(snake[0][0]+60,snake[0][1])
    

    ln_l=pg.draw.line(screen,colors[0],(snake[0][0],snake[0][1]),(snake[0][0],0),1)
    s_l=pg.draw.line(screen,colors[1],(snake[0][0],snake[0][1]),(snake[0][0],600))
    w_l=pg.draw.line(screen,colors[2],(snake[0][0],snake[0][1]),(0,snake[0][1]))
    e_l=pg.draw.line(screen,colors[3],(snake[0][0],snake[0][1]),(600,snake[0][1]))
    nw_l=pg.draw.line(screen,colors[4],(snake[0][0],snake[0][1]),(snake[0][0]-600,snake[0][1]-600))
    sw_l=pg.draw.line(screen,colors[5],(snake[0][0],snake[0][1]),(snake[0][0]-600,snake[0][1]+600))
    ne_l=pg.draw.line(screen,colors[6],(snake[0][0],snake[0][1]),(snake[0][0]+600,snake[0][1]-600))
    ne_l=pg.draw.line(screen,colors[7],(snake[0][0],snake[0][1]),(snake[0][0]+600,snake[0][1]+600))
    
    for i in range(1,len(snake)):
        snake[i]=snake_c[i-1]
        
    steps+=1
    
    if snake[0]==apple:
        apple_present=False
        snake.append(snake_c[-1])
        #snake_c=copy.deepcopy(snake)
        score+=1
        print('Apple Gone')
     
    if len(snake)==1:
        vision_body=[0, 0, 0, 0, 0, 0, 0, 0]
    elif len(snake)>1:
        vision_body=visionBody(snake,apple)
    print('Body= ',vision_body)
        
    if snake[0][0] < 0 or snake[0][0] > 540 or snake[0][1] < 0 or snake[0][1] > 540 :
        print('Wall Collision')
        running=False
        
    for i in range(1,len(snake)):
        
        if snake[i][0]==snake[0][0] and snake[i][1]==snake[0][1]:
            print('snake= ',snake,' apple= ',apple,' Score= ',score,' steps= ',steps)
            print('Body Collision')
            running=False
            
    if len(snake) != 1:        
        if (snake_c[-1][1]-snake[-1][1])<0:
            tail_direction=[0,1,0,0]
        if (snake_c[-1][1]-snake[-1][1])>0:
            tail_direction=[1,0,0,0]
        if (snake_c[-1][0]-snake[-1][0])<0:
            tail_direction=[0,0,0,1]
        if (snake_c[-1][0]-snake[-1][0])>0:
            tail_direction=[0,0,1,0]
    else:
        tail_direction=move
        
    head_direction=move
    
    vision_wall=visionWall(snake)
        
    if steps == 200:
        running=False

    print('head_direction= ',head_direction,' tail_direction= ',tail_direction, ' wall_dis= ',vision_wall)
    
    
    
    #for i in range(len(grid)):
     #   g_grid=pg.Rect(grid[i][0],grid[i][1],60,60)
      #  pg.draw.rect(screen,black,g_grid,1)
        
    g_apple=pg.Rect(apple[0]+15,apple[1]+15,30,30)
    pg.draw.rect(screen,green,g_apple)
    

    #print('*****************',colors)

    
    for i in range(len(snake)):
        if i==0:
            color=red
        else:
            color=black
        g_snake=pg.Rect(snake[i][0],snake[i][1],60,60)
        pg.draw.rect(screen,color,g_snake)
    
    pg.display.flip()
    ### NN will here at the bottom ####
# Out:
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 300)]  apple=  (120, 180)  Score=  0  steps=  0
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [5, 4, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 300)]  apple=  (120, 180)  Score=  0  steps=  1
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [6, 3, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 360)]  apple=  (120, 180)  Score=  0  steps=  2
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [7, 2, 6, 3]
# Apple=  [0, 0, 0, 0, 1, 0, 0, 0]
# snake=  [(360, 420)]  apple=  (120, 180)  Score=  0  steps=  3
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [7, 2, 7, 2]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 420)]  apple=  (120, 180)  Score=  0  steps=  4
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 6, 3]
# Apple=  [0, 0, 0, 0, 1, 0, 0, 0]
# snake=  [(360, 420)]  apple=  (120, 180)  Score=  0  steps=  5
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 420)]  apple=  (120, 180)  Score=  0  steps=  6
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 4, 5]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(240, 420)]  apple=  (120, 180)  Score=  0  steps=  7
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 3, 6]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 420)]  apple=  (120, 180)  Score=  0  steps=  8
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 2, 7]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(120, 420)]  apple=  (120, 180)  Score=  0  steps=  9
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 1, 8]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(60, 420)]  apple=  (120, 180)  Score=  0  steps=  10
#
# move: l
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [7, 2, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(0, 420)]  apple=  (120, 180)  Score=  0  steps=  11
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [6, 3, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 1, 0]
# snake=  [(0, 360)]  apple=  (120, 180)  Score=  0  steps=  12
#
# move: uu
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  uu  tail_direction=  uu  wall_dis=  [6, 3, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 1, 0]
# snake=  [(0, 360)]  apple=  (120, 180)  Score=  0  steps=  13
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [5, 4, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(0, 300)]  apple=  (120, 180)  Score=  0  steps=  14
#
# move:
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=    tail_direction=    wall_dis=  [5, 4, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(0, 300)]  apple=  (120, 180)  Score=  0  steps=  15
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [4, 5, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(0, 240)]  apple=  (120, 180)  Score=  0  steps=  16
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [3, 6, 0, 9]
# Apple=  [0, 0, 0, 1, 0, 0, 0, 0]
# snake=  [(0, 180)]  apple=  (120, 180)  Score=  0  steps=  17
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [2, 7, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(0, 120)]  apple=  (120, 180)  Score=  0  steps=  18
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [1, 8, 0, 9]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 1]
# snake=  [(0, 60)]  apple=  (120, 180)  Score=  0  steps=  19
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 1, 8]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(60, 60)]  apple=  (120, 180)  Score=  0  steps=  20
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 2, 7]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(120, 60)]  apple=  (120, 180)  Score=  0  steps=  21
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 3, 6]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 60)]  apple=  (120, 180)  Score=  0  steps=  22
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 4, 5]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(240, 60)]  apple=  (120, 180)  Score=  0  steps=  23
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 1, 0, 0]
# snake=  [(300, 60)]  apple=  (120, 180)  Score=  0  steps=  24
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [2, 7, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 120)]  apple=  (120, 180)  Score=  0  steps=  25
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [3, 6, 5, 4]
# Apple=  [0, 0, 1, 0, 0, 0, 0, 0]
# snake=  [(300, 180)]  apple=  (120, 180)  Score=  0  steps=  26
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [4, 5, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 240)]  apple=  (120, 180)  Score=  0  steps=  27
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [5, 4, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 300)]  apple=  (120, 180)  Score=  0  steps=  28
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [6, 3, 5, 4]
# Apple=  [0, 0, 0, 0, 1, 0, 0, 0]
# snake=  [(300, 360)]  apple=  (120, 180)  Score=  0  steps=  29
#
# move: u
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [5, 4, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 300)]  apple=  (120, 180)  Score=  0  steps=  30
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [6, 3, 5, 4]
# Apple=  [0, 0, 0, 0, 1, 0, 0, 0]
# snake=  [(300, 360)]  apple=  (120, 180)  Score=  0  steps=  31
