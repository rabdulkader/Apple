# %%
import numpy as np
import random,copy
import pygame as pg



frame_w=600
frame_h=600

pg.init()
screen = pg.display.set_mode((frame_w,frame_h))

white=[255,255,255]
red=[255,0,0]
black=[0,0,0]
green=[0,255,0]

running=True
apple_present=False

score=0
steps=0

x=[]
y=[]

for i in range(0,frame_w,60):
    x.append(i)
    y.append(i)

grid=[]
for i in range(len(x)):
    for j in range(len(y)):
        grid.append((x[i],y[j]))

snake_head=grid[55]
snake=[snake_head]

#             n, s, w, e, nw,sw,ne,se


def visionApple(snake,apple):
    vision_apple=[0, 0, 0, 0, 0, 0, 0, 0]
    n=snake[0][1]
    s=snake[0][1]
    w=snake[0][0]
    e=snake[0][0]

    for i in range(10):

        n-=60
        s+=60
        w-=60
        e+=60

        if apple[1]==n and apple[0]==snake[0][0]:
            vision_apple[0]=1

        if apple[1]==s and apple[0]==snake[0][0]:
            vision_apple[1]=1  

        if apple[0]==w and apple[1]==snake[0][1]:
            vision_apple[2]=1      

        if apple[0]==e and apple[1]==snake[0][1]:
            vision_apple[3]=1        

        if apple[1]==n and apple[0]==w:
            vision_apple[4]=1    

        if apple[1]==s and apple[0]==w:
            vision_apple[5]=1    

        if apple[1]==n and apple[0]==e:
            vision_apple[6]=1 

        if apple[1]==s and apple[0]==e:
            vision_apple[7]=1
            
    return vision_apple

def visionBody(snake,apple):
    vision_body=[0, 0, 0, 0, 0, 0, 0, 0]

    for i in range(1,len(snake)):
        
        n=snake[0][1]
        s=snake[0][1]
        w=snake[0][0]
        e=snake[0][0]
        
        for _ in range(10):

            n-=60
            s+=60
            w-=60
            e+=60

            if snake[i][1]==n and snake[i][0]==snake[0][0]:
                vision_body[0]=1

            if snake[i][1]==s and snake[i][0]==snake[0][0]:
                vision_body[1]=1  

            if snake[i][0]==w and snake[i][1]==snake[0][1]:
                vision_body[2]=1      

            if snake[i][0]==e and snake[i][1]==snake[0][1]:
                vision_body[3]=1        

            if snake[i][1]==n and snake[i][0]==w:
                vision_body[4]=1    

            if snake[i][1]==s and snake[i][0]==w:
                vision_body[5]=1    

            if snake[i][1]==n and snake[i][0]==e:
                vision_body[6]=1 

            if snake[i][1]==s and snake[i][0]==e:
                vision_body[7]=1
            
    return vision_body

def visionWall(snake):
    #            nw,sw,ww,ew
    vision_wall=[0, 0, 0, 0]
    
    vision_wall[0]=int((snake[0][1]/60))
    vision_wall[1]=int(((600-snake[0][1])/60)-1)
    vision_wall[2]=int((snake[0][0]/60))
    vision_wall[3]=int(((600-snake[0][0])/60)-1)
    
    return vision_wall
#def game()
while running:
    pg.event.get()
    
    if apple_present==False:
        for body in snake:
            if body in grid:
                grid.remove(body)
        apple=random.choice(grid)
        apple_present=True
        
    vision_apple=visionApple(snake,apple)
    
    print('Apple= ',vision_apple)
    
    print('snake= ',snake,' apple= ',apple,' Score= ',score,' steps= ',steps)
    
    move=input('\nmove: ')
    
    if move =='u':
        move=[1,0,0,0]
    if move =='d':
        move=[0,1,0,0]
    if move =='l':
        move=[0,0,1,0]
    if move =='r':
        move=[0,0,0,1]
    
    snake_c=copy.deepcopy(snake)
    
    
    if move ==[1,0,0,0]:
        snake[0]=(snake[0][0],snake[0][1]-60)
    if move ==[0,1,0,0]:
        snake[0]=(snake[0][0],snake[0][1]+60)
    if move ==[0,0,1,0]:
        snake[0]=(snake[0][0]-60,snake[0][1])
    if move ==[0,0,0,1]:
        snake[0]=(snake[0][0]+60,snake[0][1])
    
    for i in range(1,len(snake)):
        snake[i]=snake_c[i-1]
        
    steps+=1
    
    if snake[0]==apple:
        apple_present=False
        snake.append(snake_c[-1])
        #snake_c=copy.deepcopy(snake)
        score+=1
        print('Apple Gone')
     
    if len(snake)==1:
        vision_body=[0, 0, 0, 0, 0, 0, 0, 0]
    elif len(snake)>1:
        vision_body=visionBody(snake,apple)
    print('Body= ',vision_body)
        
    if snake[0][0] < 0 or snake[0][0] > 540 or snake[0][1] < 0 or snake[0][1] > 540 :
        print('Wall Collision')
        running=False
        
    for i in range(1,len(snake)):
        
        if snake[i][0]==snake[0][0] and snake[i][1]==snake[0][1]:
            print('snake= ',snake,' apple= ',apple,' Score= ',score,' steps= ',steps)
            print('Body Collision')
            running=False
            
    if len(snake) != 1:        
        if (snake_c[-1][1]-snake[-1][1])<0:
            tail_direction=[0,1,0,0]
        if (snake_c[-1][1]-snake[-1][1])>0:
            tail_direction=[1,0,0,0]
        if (snake_c[-1][0]-snake[-1][0])<0:
            tail_direction=[0,0,0,1]
        if (snake_c[-1][0]-snake[-1][0])>0:
            tail_direction=[0,0,1,0]
    else:
        tail_direction=move
        
    head_direction=move
    
    vision_wall=visionWall(snake)
        
    if steps == 200:
        running=False

    print('head_direction= ',head_direction,' tail_direction= ',tail_direction, ' wall_dis= ',vision_wall)
    
    screen.fill(white)
    
    for i in range(len(grid)):
        g_grid=pg.Rect(grid[i][0],grid[i][1],60,60)
        pg.draw.rect(screen,black,g_grid,1)
        
    g_apple=pg.Rect(apple[0],apple[1],60,60)
    pg.draw.rect(screen,green,g_apple)
    
    for i in range(len(snake)):
        if i==0:
            color=red
        else:
            color=black
        g_snake=pg.Rect(snake[i][0],snake[i][1],60,60)
        pg.draw.rect(screen,color,g_snake)
    
    pg.display.flip()
    ### NN will here at the bottom ####
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 300)]  apple=  (420, 540)  Score=  0  steps=  0
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [5, 4, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 300)]  apple=  (420, 540)  Score=  0  steps=  1
#
# move: r
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [5, 4, 7, 2]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 300)]  apple=  (420, 540)  Score=  0  steps=  2
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [6, 3, 7, 2]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 360)]  apple=  (420, 540)  Score=  0  steps=  3
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [7, 2, 7, 2]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 420)]  apple=  (420, 540)  Score=  0  steps=  4
#
# move: d
# Body=  [0, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [8, 1, 7, 2]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 480)]  apple=  (420, 540)  Score=  0  steps=  5
#
# move: d
# Apple Gone
# Body=  [1, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [9, 0, 7, 2]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 540), (420, 480)]  apple=  (180, 120)  Score=  1  steps=  6
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [9, 0, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 540), (420, 540)]  apple=  (180, 120)  Score=  1  steps=  7
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [9, 0, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 540), (360, 540)]  apple=  (180, 120)  Score=  1  steps=  8
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [9, 0, 4, 5]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(240, 540), (300, 540)]  apple=  (180, 120)  Score=  1  steps=  9
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [9, 0, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 540), (240, 540)]  apple=  (180, 120)  Score=  1  steps=  10
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [8, 1, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 480), (180, 540)]  apple=  (180, 120)  Score=  1  steps=  11
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [7, 2, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 420), (180, 480)]  apple=  (180, 120)  Score=  1  steps=  12
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [6, 3, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 360), (180, 420)]  apple=  (180, 120)  Score=  1  steps=  13
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [5, 4, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 300), (180, 360)]  apple=  (180, 120)  Score=  1  steps=  14
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [4, 5, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 240), (180, 300)]  apple=  (180, 120)  Score=  1  steps=  15
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [3, 6, 3, 6]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 180), (180, 240)]  apple=  (180, 120)  Score=  1  steps=  16
#
# move: u
# Apple Gone
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [2, 7, 3, 6]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(180, 120), (180, 180), (180, 240)]  apple=  (420, 300)  Score=  2  steps=  17
#
# move: u
# Body=  [0, 1, 0, 0, 0, 0, 0, 0]
# head_direction=  [1, 0, 0, 0]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [1, 8, 3, 6]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 1]
# snake=  [(180, 60), (180, 120), (180, 180)]  apple=  (420, 300)  Score=  2  steps=  18
#
# move: r
# Body=  [0, 0, 1, 0, 0, 1, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [1, 8, 4, 5]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(240, 60), (180, 60), (180, 120)]  apple=  (420, 300)  Score=  2  steps=  19
#
# move: r
# Body=  [0, 0, 1, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [1, 0, 0, 0]  wall_dis=  [1, 8, 5, 4]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(300, 60), (240, 60), (180, 60)]  apple=  (420, 300)  Score=  2  steps=  20
#
# move: r
# Body=  [0, 0, 1, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 60), (300, 60), (240, 60)]  apple=  (420, 300)  Score=  2  steps=  21
#
# move: r
# Body=  [0, 0, 1, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 7, 2]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 60), (360, 60), (300, 60)]  apple=  (420, 300)  Score=  2  steps=  22
#
# move: r
# Body=  [0, 0, 1, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [1, 8, 8, 1]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(480, 60), (420, 60), (360, 60)]  apple=  (420, 300)  Score=  2  steps=  23
#
# move: d
# Body=  [1, 0, 0, 0, 1, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [2, 7, 8, 1]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(480, 120), (480, 60), (420, 60)]  apple=  (420, 300)  Score=  2  steps=  24
#
# move: d
# Body=  [1, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [3, 6, 8, 1]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(480, 180), (480, 120), (480, 60)]  apple=  (420, 300)  Score=  2  steps=  25
#
# move: d
# Body=  [1, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [4, 5, 8, 1]
# Apple=  [0, 0, 0, 0, 0, 1, 0, 0]
# snake=  [(480, 240), (480, 180), (480, 120)]  apple=  (420, 300)  Score=  2  steps=  26
#
# move: d
# Body=  [1, 0, 0, 0, 0, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [5, 4, 8, 1]
# Apple=  [0, 0, 1, 0, 0, 0, 0, 0]
# snake=  [(480, 300), (480, 240), (480, 180)]  apple=  (420, 300)  Score=  2  steps=  27
#
# move: l
# Apple Gone
# Body=  [0, 0, 0, 1, 0, 0, 1, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [5, 4, 7, 2]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 300), (480, 300), (480, 240), (480, 180)]  apple=  (540, 480)  Score=  3  steps=  28
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [5, 4, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 1]
# snake=  [(360, 300), (420, 300), (480, 300), (480, 240)]  apple=  (540, 480)  Score=  3  steps=  29
#
# move: d
# Body=  [1, 0, 0, 0, 0, 0, 1, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [6, 3, 6, 3]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 360), (360, 300), (420, 300), (480, 300)]  apple=  (540, 480)  Score=  3  steps=  30
#
# move: r
# Body=  [1, 0, 1, 0, 1, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [6, 3, 7, 2]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 1]
# snake=  [(420, 360), (360, 360), (360, 300), (420, 300)]  apple=  (540, 480)  Score=  3  steps=  31
#
# move: r
# Body=  [0, 0, 1, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 0, 1, 0]  wall_dis=  [6, 3, 8, 1]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(480, 360), (420, 360), (360, 360), (360, 300)]  apple=  (540, 480)  Score=  3  steps=  32
#
# move: r
# Body=  [0, 0, 1, 0, 0, 0, 0, 0]
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [6, 3, 9, 0]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(540, 360), (480, 360), (420, 360), (360, 360)]  apple=  (540, 480)  Score=  3  steps=  33
#
# move: d
# Body=  [1, 0, 0, 0, 1, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [7, 2, 9, 0]
# Apple=  [0, 1, 0, 0, 0, 0, 0, 0]
# snake=  [(540, 420), (540, 360), (480, 360), (420, 360)]  apple=  (540, 480)  Score=  3  steps=  34
#
# move: d
# Apple Gone
# Body=  [1, 0, 0, 0, 1, 0, 0, 0]
# head_direction=  [0, 1, 0, 0]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [8, 1, 9, 0]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(540, 480), (540, 420), (540, 360), (480, 360), (420, 360)]  apple=  (360, 0)  Score=  4  steps=  35
#
# move: l
# Body=  [1, 0, 0, 1, 0, 0, 1, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [8, 1, 8, 1]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(480, 480), (540, 480), (540, 420), (540, 360), (480, 360)]  apple=  (360, 0)  Score=  4  steps=  36
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 1, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 0, 0, 1]  wall_dis=  [8, 1, 7, 2]
# Apple=  [0, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(420, 480), (480, 480), (540, 480), (540, 420), (540, 360)]  apple=  (360, 0)  Score=  4  steps=  37
#
# move: l
# Body=  [0, 0, 0, 1, 0, 0, 0, 0]
# head_direction=  [0, 0, 1, 0]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [8, 1, 6, 3]
# Apple=  [1, 0, 0, 0, 0, 0, 0, 0]
# snake=  [(360, 480), (420, 480), (480, 480), (540, 480), (540, 420)]  apple=  (360, 0)  Score=  4  steps=  38
#
# move: r
# Body=  [0, 0, 1, 1, 0, 0, 0, 0]
# snake=  [(420, 480), (360, 480), (420, 480), (480, 480), (540, 480)]  apple=  (360, 0)  Score=  4  steps=  39
# Body Collision
# head_direction=  [0, 0, 0, 1]  tail_direction=  [0, 1, 0, 0]  wall_dis=  [8, 1, 7, 2]
